# %% [markdown]
# # Exploratory Data Analysis (EDA) on Paris 2024 Olympics Dataset
# TEAM MEMBERS:
#
# MONIKA HS
#
# SRUSHTI K YALAGI

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  Loading the  Dataset

# %%
df = pd.read_csv('C:\\path\\athletedata.csv') 
medal = pd.read_csv('C:\\path\\medals_total.csv')
medalist_data = pd.read_csv('C:\\path\\medallists.csv')

# %% [markdown]
#  Initial Data Overview

# %%
# Check the first few rows
df.head()
# Out:
#       code               name     name_short            name_tv gender  \
# 0  1532872   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male
# 1  1532873     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male
# 2  1532874    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male
# 3  1532944  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male
# 4  1532945    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male
#
#   country_code  country nationality nationality_long nationality_code  ...  \
# 0          ARM  Armenia     Armenia          Armenia              ARM  ...
# 1          ARM  Armenia     Armenia          Armenia              ARM  ...
# 2          ARM  Armenia     Armenia          Armenia              ARM  ...
# 3          ARM  Armenia     Armenia          Armenia              ARM  ...
# 4          ARM  Armenia     Armenia          Armenia              ARM  ...
#
#    weight    disciplines                      events  birth_date birth_place  \
# ...

# %%
df.tail()
# Out:
#           code             name name_short          name_tv  gender  \
# 11108  4986655   ADA ETO Sefora  ADA ETO S   Sefora ADA ETO  Female
# 11109  9460001  LIUZZI Emanuela   LIUZZI E  Emanuela LIUZZI  Female
# 11110  1972077     BOERS Isayah        NaN              NaN    Male
# 11111  1899865      STAUT Kevin        NaN              NaN    Male
# 11112  1924402  CARVELL Charlie        NaN              NaN    Male
#
#       country_code            country        nationality   nationality_long  \
# 11108          GEQ  Equatorial Guinea  Equatorial Guinea  Equatorial Guinea
# 11109          ITA              Italy                NaN                NaN
# 11110          NED        Netherlands        Netherlands        Netherlands
# 11111          FRA             France             France             France
# 11112          GBR      Great Britain      Great Britain      Great Britain
#
#       nationality_code  ...  weight    disciplines  \
# ...

# %%
df.shape
# Out:
# (11113, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   code              11113 non-null  int64
#  1   name              11113 non-null  object
#  2   name_short        11110 non-null  object
#  3   name_tv           11110 non-null  object
#  4   gender            11113 non-null  object
#  5   country_code      11113 non-null  object
#  6   country           11113 non-null  object
#  7   nationality       11110 non-null  object
#  8   nationality_long  11110 non-null  object
#  9   nationality_code  11110 non-null  object
#  10  height            11110 non-null  float64
#  11  weight            11108 non-null  float64
#  12  disciplines       11113 non-null  object
#  13  events            11113 non-null  object
#  14  birth_date        11113 non-null  object
#  15  birth_place       8727 non-null   object
# ...

# %%
medal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  92 non-null     object
#  1   country       92 non-null     object
#  2   country_long  92 non-null     object
#  3   Gold Medal    92 non-null     int64
#  4   Silver Medal  92 non-null     int64
#  5   Bronze Medal  92 non-null     int64
#  6   Total         92 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 5.2+ KB

# %%
medal.head()
# Out:
#   country_code        country                country_long  Gold Medal  \
# 0          USA  United States    United States of America          40
# 1          CHN          China  People's Republic of China          40
# 2          JPN          Japan                       Japan          20
# 3          AUS      Australia                   Australia          18
# 4          FRA         France                      France          16
#
#    Silver Medal  Bronze Medal  Total
# 0            44            42    126
# 1            27            24     91
# 2            12            13     45
# 3            19            16     53
# 4            26            22     64

# %%
medal.tail()
# Out:
#    country_code    country country_long  Gold Medal  Silver Medal  \
# 87          PER       Peru         Peru           0             0
# 88          QAT      Qatar        Qatar           0             0
# 89          SGP  Singapore    Singapore           0             0
# 90          SVK   Slovakia     Slovakia           0             0
# 91          ZAM     Zambia       Zambia           0             0
#
#     Bronze Medal  Total
# 87             1      1
# 88             1      1
# 89             1      1
# 90             1      1
# 91             1      1

# %%
medalist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315 entries, 0 to 2314
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   medal_date        2315 non-null   object
#  1   medal_type        2315 non-null   object
#  2   medal_code        2314 non-null   float64
#  3   name              2315 non-null   object
#  4   gender            2315 non-null   object
#  5   country_code      2315 non-null   object
#  6   country           2315 non-null   object
#  7   country_long      2315 non-null   object
#  8   nationality_code  2314 non-null   object
#  9   nationality       2314 non-null   object
#  10  nationality_long  2314 non-null   object
#  11  team              1555 non-null   object
#  12  team_gender       1555 non-null   object
#  13  discipline        2315 non-null   object
#  14  event             2315 non-null   object
#  15  event_type        2315 non-null   object
# ...

# %%
medalist_data.head()
# Out:
#    medal_date    medal_type  medal_code             name  gender country_code  \
# 0  2024-07-27    Gold Medal         1.0  EVENEPOEL Remco    Male          BEL
# 1  2024-07-27  Silver Medal         2.0    GANNA Filippo    Male          ITA
# 2  2024-07-27  Bronze Medal         3.0    van AERT Wout    Male          BEL
# 3  2024-07-27    Gold Medal         1.0      BROWN Grace  Female          AUS
# 4  2024-07-27  Silver Medal         2.0   HENDERSON Anna  Female          GBR
#
#          country   country_long nationality_code    nationality  ... team  \
# 0        Belgium        Belgium              BEL        Belgium  ...  NaN
# 1          Italy          Italy              ITA          Italy  ...  NaN
# 2        Belgium        Belgium              BEL        Belgium  ...  NaN
# 3      Australia      Australia              AUS      Australia  ...  NaN
# 4  Great Britain  Great Britain              GBR  Great Britain  ...  NaN
#
# ...

# %%
medalist_data.tail()
# Out:
#       medal_date    medal_type  medal_code                name  gender  \
# 2310  2024-08-10  Bronze Medal         3.0  CENTOFANTI Martina  Female
# 2311  2024-08-10  Bronze Medal         3.0      DURANTI Agnese  Female
# 2312  2024-08-10  Bronze Medal         3.0    MAURELLI Alessia  Female
# 2313  2024-08-10  Bronze Medal         3.0    MOGUREAN Daniela  Female
# 2314  2024-08-10  Bronze Medal         3.0         PARIS Laura  Female
#
#      country_code country country_long nationality_code nationality  ...  \
# 2310          ITA   Italy        Italy              ITA       Italy  ...
# 2311          ITA   Italy        Italy              ITA       Italy  ...
# 2312          ITA   Italy        Italy              ITA       Italy  ...
# 2313          ITA   Italy        Italy              ITA       Italy  ...
# 2314          ITA   Italy        Italy              ITA       Italy  ...
#
#        team team_gender           discipline             event event_type  \
# ...

# %% [markdown]
#  Data Cleaning
#
#  Handling Missing Values

# %%
# Check for missing values
df.isnull().sum()
# Out:
# code                   0
# name                   0
# name_short             3
# name_tv                3
# gender                 0
# country_code           0
# country                0
# nationality            3
# nationality_long       3
# nationality_code       3
# height                 3
# weight                 5
# disciplines            0
# events                 0
# birth_date             0
# birth_place         2386
# birth_country       1638
# occupation          1529
# education           5575
# lang                 508
# coach               2891
# dtype: int64

# %%
df.describe()
# Out:
#                code        height        weight
# count  1.111300e+04  11110.000000  11108.000000
# mean   1.887418e+06     81.798830      2.211919
# std    3.588006e+05     89.508247     13.109608
# min    1.532872e+06      0.000000      0.000000
# 25%    1.888184e+06      0.000000      0.000000
# 50%    1.918840e+06      0.000000      0.000000
# 75%    1.948950e+06    177.000000      0.000000
# max    9.460001e+06    222.000000    113.000000

# %% [markdown]
# Handling missing data:
# Drop missing values or fill them with appropriate values (mean, median, etc.).

# %%
df['height'].fillna(df['height'].mean(), inplace=True)
df['weight'].fillna(df['weight'].mean(), inplace=True)

# %%
#Handle Irrelevant or Redundant Columns:

df.drop(columns=['name_short', 'name_tv'], inplace=True)

# %%
df.drop(columns=['birth_place', 'birth_country','lang'], inplace=True)

# %%
df.drop(columns=['nationality_long', 'nationality_code'], inplace=True)

# %%
# Fill missing values for categorical columns with 'Unknown' or the mode
df['education'].fillna(df['education'].mode()[0], inplace=True)
df['occupation'].fillna(df['occupation'].mode()[0], inplace=True)
df['coach'].fillna('Unknown', inplace=True)

# Fill missing nationality-related fields
df['nationality'].fillna('Unknown', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          11113 non-null  int64
#  1   name          11113 non-null  object
#  2   gender        11113 non-null  object
#  3   country_code  11113 non-null  object
#  4   country       11113 non-null  object
#  5   nationality   11113 non-null  object
#  6   height        11113 non-null  float64
#  7   weight        11113 non-null  float64
#  8   disciplines   11113 non-null  object
#  9   events        11113 non-null  object
#  10  birth_date    11113 non-null  object
#  11  occupation    11113 non-null  object
#  12  education     11113 non-null  object
#  13  coach         11113 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.2+ MB

# %% [markdown]
#  Convert birth_date to DateTime

# %%
df['birth_date'] = pd.to_datetime(df['birth_date'],format='%d/%m/%Y',errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          11113 non-null  int64
#  1   name          11113 non-null  object
#  2   gender        11113 non-null  object
#  3   country_code  11113 non-null  object
#  4   country       11113 non-null  object
#  5   nationality   11113 non-null  object
#  6   height        11113 non-null  float64
#  7   weight        11113 non-null  float64
#  8   disciplines   11113 non-null  object
#  9   events        11113 non-null  object
#  10  birth_date    11113 non-null  datetime64[ns]
#  11  occupation    11113 non-null  object
#  12  education     11113 non-null  object
#  13  coach         11113 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# Remove duplicate records, if any.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Check Data Consistency:
#
# Ensure consistency in categorical data (e.g., gender, country, nationality).

# %%
print(df['gender'].value_counts())
df['gender'] = df['gender'].str.upper()  # Standardize gender as uppercase
# Out:
# Male      5658
# Female    5455
# Name: gender, dtype: int64

# %%
#Check for Unique Values:
print(len(df))
print(df['code'].nunique())
# Out:
# 11113
# 11113

# %%
medal.drop(columns=['country_long'], inplace=True)

# %%
medal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  92 non-null     object
#  1   country       92 non-null     object
#  2   Gold Medal    92 non-null     int64
#  3   Silver Medal  92 non-null     int64
#  4   Bronze Medal  92 non-null     int64
#  5   Total         92 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 4.4+ KB

# %%
medalist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315 entries, 0 to 2314
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   medal_date        2315 non-null   object
#  1   medal_type        2315 non-null   object
#  2   medal_code        2314 non-null   float64
#  3   name              2315 non-null   object
#  4   gender            2315 non-null   object
#  5   country_code      2315 non-null   object
#  6   country           2315 non-null   object
#  7   country_long      2315 non-null   object
#  8   nationality_code  2314 non-null   object
#  9   nationality       2314 non-null   object
#  10  nationality_long  2314 non-null   object
#  11  team              1555 non-null   object
#  12  team_gender       1555 non-null   object
#  13  discipline        2315 non-null   object
#  14  event             2315 non-null   object
#  15  event_type        2315 non-null   object
# ...

# %%
medalist_data.drop(columns=['country_long','medal_code','nationality_code','nationality_long','team','team_gender','url_event','code_team','is_medallist',], inplace=True)

# %%
medalist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315 entries, 0 to 2314
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   medal_date    2315 non-null   object
#  1   medal_type    2315 non-null   object
#  2   name          2315 non-null   object
#  3   gender        2315 non-null   object
#  4   country_code  2315 non-null   object
#  5   country       2315 non-null   object
#  6   nationality   2314 non-null   object
#  7   discipline    2315 non-null   object
#  8   event         2315 non-null   object
#  9   event_type    2315 non-null   object
#  10  birth_date    2315 non-null   object
#  11  code_athlete  2315 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 217.2+ KB

# %%
medalist_data['birth_date'] = pd.to_datetime(df['birth_date'],format='%d/%m/%Y',errors='coerce')

# %%
medalist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315 entries, 0 to 2314
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   medal_date    2315 non-null   object
#  1   medal_type    2315 non-null   object
#  2   name          2315 non-null   object
#  3   gender        2315 non-null   object
#  4   country_code  2315 non-null   object
#  5   country       2315 non-null   object
#  6   nationality   2314 non-null   object
#  7   discipline    2315 non-null   object
#  8   event         2315 non-null   object
#  9   event_type    2315 non-null   object
#  10  birth_date    2315 non-null   datetime64[ns]
#  11  code_athlete  2315 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 217.2+ KB

# %% [markdown]
# Feature Engineering:birth_date, birth_year, and birth_month, you can derive additional features like age:

# %%
df['birth_year'] = df['birth_date'].dt.year
df['birth_month'] = df['birth_date'].dt.month

# %%
from datetime import datetime
current_year = datetime.now().year
df['age'] = current_year - df['birth_year']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11113 entries, 0 to 11112
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          11113 non-null  int64
#  1   name          11113 non-null  object
#  2   gender        11113 non-null  object
#  3   country_code  11113 non-null  object
#  4   country       11113 non-null  object
#  5   nationality   11113 non-null  object
#  6   height        11113 non-null  float64
#  7   weight        11113 non-null  float64
#  8   disciplines   11113 non-null  object
#  9   events        11113 non-null  object
#  10  birth_date    11113 non-null  datetime64[ns]
#  11  occupation    11113 non-null  object
#  12  education     11113 non-null  object
#  13  coach         11113 non-null  object
#  14  birth_year    11113 non-null  int64
#  15  birth_month   11113 non-null  int64
#  16  age           11113 non-null  int64
# ...

# %% [markdown]
# # EDA Visualizations

# %%
# Create a histogram for age distribution
plt.figure(figsize=(14, 8))
sns.histplot(df['age'], bins=30, kde=True, color='blue', edgecolor='black')

# Add titles and labels
plt.title('Age Distribution of Athletes')
plt.xlabel('Age')
plt.ylabel('Number of Athletes')

plt.tight_layout()  # Adjust layout
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='age', data=df, palette='pastel')
plt.title('Box Plot of Age Distribution')
plt.xlabel('Age')
plt.show()

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers by keeping only the values within the IQR bounds
df_filtered = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound)]

# Plot the boxplot again without the outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x='age', data=df_filtered, palette='pastel')
plt.title('Box Plot of Age Distribution (Without Outliers)')
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['gender'], bins=2)
plt.title('Gender Distribution of Athletes')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Group by country and count the number of athletes
athlete_counts = df.groupby('country')['name'].count().reset_index()
athlete_counts.columns = ['Country', 'Athlete Count']

# Get the top 50 countries by athlete count
top_50_countries = athlete_counts.nlargest(50, 'Athlete Count')

# Create a bar chart for the top 50 countries
plt.figure(figsize=(12, 8))
plt.bar(top_50_countries['Country'], top_50_countries['Athlete Count'], color='skyblue')
plt.title('Top 50 Countries by Athlete Count')
plt.xlabel('Country')
plt.ylabel('Number of Athletes')
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
event_counts = df['events'].value_counts().reset_index()
event_counts.columns = ['Event', 'Count']
top_events = event_counts.head(20)

plt.figure(figsize=(14, 8))
sns.barplot(x='Count', y='Event', data=top_events, palette='magma')
plt.title('Top 20 Events by Number of Athletes')
plt.xlabel('Number of Athletes')
plt.ylabel('Event')
plt.show()

# %%
plt.figure(figsize=(10, 8))
correlation = df[['height', 'weight', 'age']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
top_countries = medal.nlargest(43, 'Total')  # Get the top 30 countries

# Set the country as the index for easier plotting
top_countries.set_index('country', inplace=True)

# Create a stacked bar chart
plt.figure(figsize=(14, 8))
top_countries[['Gold Medal', 'Silver Medal', 'Bronze Medal']].plot(kind='bar', stacked=True, color=['gold', 'silver', '#cd7f32'], ax=plt.gca())

# Add labels and title
plt.title('Stacked Medal Distribution for Top 30 Countries')
plt.xlabel('Countries')
plt.ylabel('Number of Medals')

plt.legend(title='Medal Type')

plt.tight_layout()  # Adjust layout
plt.show()

# %%
selected_country = 'United States'  # Change to your desired country
country_data = medal[medal['country'] == selected_country].iloc[0]

# Data for the bar chart
labels = ['Gold', 'Silver', 'Bronze']
sizes = [country_data['Gold Medal'], country_data['Silver Medal'], country_data['Bronze Medal']]

# Create a bar chart
plt.figure(figsize=(8, 5))
plt.bar(labels, sizes, color=['gold', 'silver', '#cd7f32'])
plt.title(f'Medal Counts for {selected_country}')
plt.xlabel('Medal Type')
plt.ylabel('Count')
plt.ylim(0, max(sizes) + 5)  # Add some space above the highest bar

# Show the value on top of the bars
for i, v in enumerate(sizes):
    plt.text(i, v + 0.2, str(v), ha='center')

plt.tight_layout()
plt.show()

# %%
top_athletes = medalist_data['name'].value_counts().head(10)
plt.figure(figsize=(14, 8))
sns.barplot(x=top_athletes.values, y=top_athletes.index, palette='magma')
plt.title('Top 10 Athletes by Number of Medals')
plt.xlabel('Number of Medals')
plt.ylabel('Athlete Name')
plt.show()
